# %%
import os
import pandas as pd
import numpy as np
import warnings
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
import smote
import imblearn
from collections import Counter
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
print(imblearn.__version__)
# Out:
# 0.13.0

# %%
bnplData = pd.read_csv("/workspaces/workspace/data_for_synthetic_test.csv", low_memory=False)
bnplData.shape
# Out:
# (33123, 195)

# %%
column_names = bnplData.columns.tolist()
print(column_names)
# Out:
# ['TXN_UID', 'OUTCOME', 'BAD', 'AGE', 'BALANCE', 'BALANCE_A', 'BALANCE_AGE', 'BALANCE_C', 'CCAAMC060030A', 'CCAASC060001A', 'CCAATC060030A', 'CCAATC060030R', 'CCAATD060030S', 'CCACSD060001R', 'CCAUTD060030R', 'CCHACT730001X', 'CCHAID021000A', 'CCHAMC007000A', 'CCHAMC021000A', 'CCHAMC182001A', 'CCHAMC182007A', 'CCHAMC365001A', 'CCHAMC365182R', 'CCHAMC730001A', 'CCHAMC730014A', 'CCHAMC730365R', 'CCHAMD090001R', 'CCHAMD090001X', 'CCHAMD182001R', 'CCHAMD182001X', 'CCHAMD730001X', 'CCHAMT730001X', 'CCHAST730001X', 'CCHAZC365001A', 'CCHAZT730001X', 'CCHCMC730000A', 'CCHDMD021000N', 'CCHDMD730001N', 'CCHDMT021000N', 'CCHDMT730001N', 'CCHUMC730001A', 'CCHXID006000B', 'CCHXID090001B', 'CCHXMC021000A', 'CCHXMC730001A', 'CCHXMD009000A', 'CCHXMD180999A', 'CCHXMS021000C', 'CCHXZC730001X', 'CCIATC365001A', 'CCIATT365001X', 'CCIDTT365001R', 'CCIUTD365001R', 'CCIXTC365001A', 'CCMAMS030000C', 'CCMDMC021000A', 'CCMXAC003000A', 'CCMXAC021000A', 'CCMXMS000000X', 'CCMXMS004000X', 'CCMXMS007000X', 'CCMXMS030000C', 'CCPACC395030A', 'CCPACD395030M', 'CCPACD395030S', 'CCPACD395030V', 'CCPUCD395030R', 'CCQACC395030A', 'CCQACD395030M', 'CCQACD395030S', 'CCQACD395030V', 'CCQUCD395030R', 'CCSACD030001S', 'CCSACD060001S', 'CCSDBT060000N', 'CCSDCT060000N', 'CCSDET060000N', 'CCSDRT060000N', 'CHECK_NUMBER', 'CPDDMC730000A', 'CPDDMT730000N', 'CPDXMT730000N', 'CPHDBC090001A', 'CPHDBT090001N', 'CPHDDC730000A', 'CPHDDT730000N', 'CPHXBT090001N', 'CPHXDT730000N', 'CPMDBC090001A', 'CPMDMT090001N', 'CPMXMT090001N', 'CPTAMC730001A', 'CPTAMD730001A', 'CPTAMT730001N', 'CPTCMD730001A', 'CPTDMC730001A', 'CPTDMT730001N', 'CPTXMT730001N', 'DIFF_FA_AVAIL_BAL', 'DIFF_FA_BAL', 'DIFF_FA_CUR_BAL', 'EMLAGE_ADVICE_ID', 'EMLAGE_BILL_ADDR_TO_FULL_NAME', 'EMLAGE_BILL_ADDR_TO_LAST_NAME', 'EMLAGE_DIGITAL_ID_SCORE', 'EMLAGE_DOMAIN_CREATE_DAYS', 'EMLAGE_DOMAIN_REL_INFO_ID', 'EMLAGE_DOMAIN_RISK_LVL_ID', 'EMLAGE_EMAIL_TO_BILL_ADDR', 'EMLAGE_EMAIL_TO_FULL_NAME', 'EMLAGE_EMAIL_TO_IP', 'EMLAGE_EMAIL_TO_LAST_NAME', 'EMLAGE_EMAIL_TO_PHONE', 'EMLAGE_FIRST_SEEN_DAYS', 'EMLAGE_FRAUD_SCORE', 'EMLAGE_IP_FULL_NAME', 'EMLAGE_IP_LAST_NAME', 'EMLAGE_IP_TO_BILL_ADDR', 'EMLAGE_IP_TO_PHONE', 'EMLAGE_PHONE_TO_BILL_ADDR', 'EMLAGE_PHONE_TO_FULL_NAME', 'EMLAGE_PHONE_TO_LAST_NAME', 'EMLAGE_REASON_ID', 'EMLAGE_RESPONSE_STATUS_CODE', 'EMLAGE_RISK_BAND_ID', 'EMLAGE_SM_FRIENDS', 'EMLAGE_STATUS_ID', 'EMLAGE_TOTAL_HITS', 'EMLAGE_UNIQUE_HITS', 'FACE_AMOUNT_ROUND', 'PCNT_DIFF_FA_AVAIL_BAL', 'PCNT_DIFF_FA_BAL', 'PCNT_DIFF_FA_CUR_BAL', 'RATIO_FA_AVAIL_BAL', 'RATIO_FA_BAL', 'RATIO_FA_CUR_BAL', 'SPECTRUM_RSS2302', 'TRAN_AMOUNT', 'YODLEE_ATTRIBUTE_AGE', 'YODLEE_AVG_CREDIT', 'YODLEE_AVG_DIRDEP', 'YODLEE_AVG_RUNBAL', 'YODLEE_DAYS_LAST_DIRDEP', 'YODLEE_DAY_ACC_HIST', 'AREA_CODE', 'CCHXMC730001X', 'CCHXMT730001C', 'CHAIN_NO', 'CONS_HOME_PHONE', 'DAY_OF_WEEK', 'DELIVERY_CODE', 'DL_SWIPE_INDICATOR', 'EMLAGE_BILL_RISK_COUNTRY', 'EMLAGE_CITY_MATCH', 'EMLAGE_DIS_DESCR', 'EMLAGE_DOMAIN_CAT', 'EMLAGE_DOMAIN_CNTRY_MATCH', 'EMLAGE_DOMAIN_CO', 'EMLAGE_DOMAIN_CORP', 'EMLAGE_DOMAIN_COUNTRY', 'EMLAGE_DOMAIN_EXISTS', 'EMLAGE_DOMAIN_NAME', 'EMLAGE_DOMAIN_RISK_CNTRY', 'EMLAGE_DOMAIN_RISK_LVL', 'EMLAGE_EMAIL_EXIST', 'EMLAGE_FRAUD_TYPE', 'EMLAGE_IP_RISK_LVL', 'EMLAGE_NAME_MATCH', 'EMLAGE_PHONE_BILL_LOGIC', 'EMLAGE_PHONE_CARRIER_TYPE', 'EMLAGE_PHONE_OWNER_MATCH', 'EMLAGE_PHONE_STATUS', 'EMLAGE_RESPONSE_STATUS', 'EMLAGE_SHIP_FORWARD', 'EMLAGE_STATUS', 'FM_SCAN_CODE', 'ID_CODE', 'ID_STN_STATE_MATCH_IND', 'LOCAL_HOUR', 'MRCH_PRODUCT_CODE', 'NYCE_AVAIL_FUNDS', 'NYCE_RESP_CODE', 'POSITIVE_GRADE', 'SPECTRUM_ALERT_CODE1', 'SPECTRUM_ALERT_CODE2', 'SPECTRUM_ALERT_CODE3', 'SPECTRUM_ALERT_CODE4', 'SPECTRUM_ALERT_CODE5', 'SPECTRUM_RSS2302_REASON_CODE1', 'SPECTRUM_RSS2302_REASON_CODE2', 'SPECTRUM_RSS2302_REASON_CODE3', 'SPECTRUM_RSS2302_REASON_CODE4', 'SPECTRUM_RSS2302_REASON_CODE5', 'STATION_STATE', 'ZIP3']

# %%
#separate target from features
#X = bnplData[['TXN_UID','AGE','BALANCE_A','SPECTRUM_RSS2302']]
X = bnplData.drop(['BAD','OUTCOME'], axis=1)
y = bnplData['OUTCOME']

# %%
#show distribution of outcome
bnplData['OUTCOME'].value_counts()
# Out:
# OUTCOME
# NO ATTEMPTS    23863
# DECLINED        5783
# GOOD            3262
# LOSS             215
# Name: count, dtype: int64

# %% [markdown]
# Need to impute missing values to avoid errors

# %%
# Select numerical columns
numerical_cols = [cname for cname in X.columns if 
                X[cname].dtype in ['int64', 'float64']]
numerical_cols
# Out:
# ['TXN_UID',
#  'AGE',
#  'BALANCE',
#  'BALANCE_A',
#  'BALANCE_AGE',
#  'BALANCE_C',
#  'CCAAMC060030A',
#  'CCAASC060001A',
#  'CCAATC060030A',
#  'CCAATC060030R',
#  'CCAATD060030S',
#  'CCACSD060001R',
#  'CCAUTD060030R',
#  'CCHACT730001X',
#  'CCHAID021000A',
#  'CCHAMC007000A',
#  'CCHAMC021000A',
#  'CCHAMC182001A',
#  'CCHAMC182007A',
#  'CCHAMC365001A',
#  'CCHAMC365182R',
#  'CCHAMC730001A',
#  'CCHAMC730014A',
#  'CCHAMC730365R',
#  'CCHAMD090001R',
#  'CCHAMD090001X',
#  'CCHAMD182001R',
#  'CCHAMD182001X',
#  'CCHAMD730001X',
#  'CCHAMT730001X',
#  'CCHAST730001X',
#  'CCHAZC365001A',
#  'CCHAZT730001X',
#  'CCHCMC730000A',
#  'CCHDMD021000N',
#  'CCHDMD730001N',
#  'CCHDMT021000N',
#  'CCHDMT730001N',
#  'CCHUMC730001A',
#  'CCHXID006000B',
#  'CCHXID090001B',
#  'CCHXMC021000A',
#  'CCHXMC730001A',
#  'CCHXMD009000A',
#  'CCHXMD180999A',
#  'CCHXMS021000C',
#  'CCHXZC730001X',
#  'CCIATC365001A',
#  'CCIATT365001X',
#  'CCIDTT365001R',
#  'CCIUTD365001R',
#  'CCIXTC365001A',
#  'CCMAMS030000C',
#  'CCMDMC021000A',
#  'CCMXAC003000A',
#  'CCMXAC021000A',
#  'CCMXMS000000X',
#  'CCMXMS004000X',
#  'CCMXMS007000X',
#  'CCMXMS030000C',
#  'CCPACC395030A',
#  'CCPACD395030M',
#  'CCPACD395030S',
#  'CCPACD395030V',
#  'CCPUCD395030R',
#  'CCQACC395030A',
#  'CCQACD395030M',
#  'CCQACD395030S',
#  'CCQACD395030V',
#  'CCQUCD395030R',
#  'CCSACD030001S',
#  'CCSACD060001S',
#  'CCSDBT060000N',
#  'CCSDCT060000N',
#  'CCSDET060000N',
#  'CCSDRT060000N',
#  'CHECK_NUMBER',
#  'CPDDMC730000A',
#  'CPDDMT730000N',
#  'CPDXMT730000N',
#  'CPHDBC090001A',
#  'CPHDBT090001N',
#  'CPHDDC730000A',
#  'CPHDDT730000N',
#  'CPHXBT090001N',
#  'CPHXDT730000N',
#  'CPMDBC090001A',
#  'CPMDMT090001N',
#  'CPMXMT090001N',
#  'CPTAMC730001A',
#  'CPTAMD730001A',
#  'CPTAMT730001N',
#  'CPTCMD730001A',
#  'CPTDMC730001A',
#  'CPTDMT730001N',
#  'CPTXMT730001N',
#  'DIFF_FA_AVAIL_BAL',
#  'DIFF_FA_BAL',
#  'DIFF_FA_CUR_BAL',
#  'EMLAGE_ADVICE_ID',
#  'EMLAGE_BILL_ADDR_TO_FULL_NAME',
#  'EMLAGE_BILL_ADDR_TO_LAST_NAME',
#  'EMLAGE_DIGITAL_ID_SCORE',
#  'EMLAGE_DOMAIN_CREATE_DAYS',
#  'EMLAGE_DOMAIN_REL_INFO_ID',
#  'EMLAGE_DOMAIN_RISK_LVL_ID',
#  'EMLAGE_EMAIL_TO_BILL_ADDR',
#  'EMLAGE_EMAIL_TO_FULL_NAME',
#  'EMLAGE_EMAIL_TO_IP',
#  'EMLAGE_EMAIL_TO_LAST_NAME',
#  'EMLAGE_EMAIL_TO_PHONE',
#  'EMLAGE_FIRST_SEEN_DAYS',
#  'EMLAGE_FRAUD_SCORE',
#  'EMLAGE_IP_FULL_NAME',
#  'EMLAGE_IP_LAST_NAME',
#  'EMLAGE_IP_TO_BILL_ADDR',
#  'EMLAGE_IP_TO_PHONE',
#  'EMLAGE_PHONE_TO_BILL_ADDR',
#  'EMLAGE_PHONE_TO_FULL_NAME',
#  'EMLAGE_PHONE_TO_LAST_NAME',
#  'EMLAGE_REASON_ID',
#  'EMLAGE_RESPONSE_STATUS_CODE',
#  'EMLAGE_RISK_BAND_ID',
#  'EMLAGE_SM_FRIENDS',
#  'EMLAGE_STATUS_ID',
#  'EMLAGE_TOTAL_HITS',
#  'EMLAGE_UNIQUE_HITS',
#  'FACE_AMOUNT_ROUND',
#  'PCNT_DIFF_FA_AVAIL_BAL',
#  'PCNT_DIFF_FA_BAL',
#  'PCNT_DIFF_FA_CUR_BAL',
#  'RATIO_FA_AVAIL_BAL',
#  'RATIO_FA_BAL',
#  'RATIO_FA_CUR_BAL',
#  'SPECTRUM_RSS2302',
#  'TRAN_AMOUNT',
#  'YODLEE_ATTRIBUTE_AGE',
#  'YODLEE_AVG_CREDIT',
#  'YODLEE_AVG_DIRDEP',
#  'YODLEE_AVG_RUNBAL',
#  'YODLEE_DAYS_LAST_DIRDEP',
#  'YODLEE_DAY_ACC_HIST',
#  'AREA_CODE',
#  'CHAIN_NO',
#  'CONS_HOME_PHONE',
#  'DAY_OF_WEEK',
#  'DELIVERY_CODE',
#  'ID_CODE',
#  'LOCAL_HOUR',
#  'MRCH_PRODUCT_CODE',
#  'SPECTRUM_ALERT_CODE4',
#  'SPECTRUM_ALERT_CODE5',
#  'ZIP3']

# %%
# Impute numeric columns, simple fill with -999 value
my_numeric_imputer = SimpleImputer(strategy='constant', fill_value=-999)
num_X = X[numerical_cols]
imputed_num_X = pd.DataFrame(my_numeric_imputer.fit_transform(num_X))

# Imputation removed column names; put them back
imputed_num_X.columns = num_X.columns
imputed_num_X.head()
# Out:
#         TXN_UID    AGE  BALANCE  BALANCE_A  BALANCE_AGE  BALANCE_C  \
# 0  1.244170e+12 -999.0  -999.00    -999.00       -999.0    -999.00
# 1  1.244170e+12   37.0 -9999.98   -9999.98         -1.0   -9999.98
# 2  1.244170e+12   24.0  1158.64    1153.64         -1.0    1158.64
# 3  1.244170e+12   36.0    35.89     106.02         -1.0      35.89
# 4  1.244170e+12   27.0 -9999.98   -9999.98         -1.0   -9999.98
#
#    CCAAMC060030A  CCAASC060001A  CCAATC060030A  CCAATC060030R  ...  CHAIN_NO  \
# 0         -999.0         -999.0         -999.0    -999.000000  ...    -999.0
# 1        18528.0            0.0            1.0       0.000054  ...  130000.0
# 2          653.0            0.0          542.0       0.830015  ...  160224.0
# 3         2787.0            0.0         2415.0       0.866523  ...  168411.0
# 4          302.0            0.0            5.0       0.016556  ...  139767.0
#
#    CONS_HOME_PHONE  DAY_OF_WEEK  DELIVERY_CODE  ID_CODE  LOCAL_HOUR  \
# 0    -9.990000e+02       -999.0         -999.0   -999.0      -999.0
# 1     9.376032e+09          5.0            0.0     -1.0         7.0
# 2     4.057616e+09          5.0            0.0     -1.0        10.0
# 3     2.818985e+09          5.0            0.0     -1.0        10.0
# 4     5.417015e+09          5.0            0.0     -1.0         9.0
#
#    MRCH_PRODUCT_CODE  SPECTRUM_ALERT_CODE4  SPECTRUM_ALERT_CODE5   ZIP3
# 0             -999.0                -999.0                -999.0 -999.0
# 1               -1.0                -999.0                -999.0  945.0
# 2               -1.0                -999.0                -999.0  731.0
# 3               -1.0                -999.0                -999.0  775.0
# 4               -1.0                -999.0                -999.0  978.0
#
# [5 rows x 153 columns]

# %%
#Impute character values
categorical_cols = [cname for cname in X.columns if
                    X[cname].nunique() < 21 and 
                    X[cname].dtype == "object"]
categorical_cols

my_categorical_imputer = SimpleImputer(strategy='constant', fill_value='Z')
char_X = X[categorical_cols]
imputed_char_X = pd.DataFrame(my_categorical_imputer.fit_transform(char_X))

# Imputation removed column names; put them back
imputed_char_X.columns = char_X.columns

imputed_char_X.head(10)
# Out:
#   CCHXMT730001C DL_SWIPE_INDICATOR EMLAGE_BILL_RISK_COUNTRY EMLAGE_CITY_MATCH  \
# 0             Z                  Z                        Z                 Z
# 1             Z                  M                       No                -1
# 2             Z                  M                       No                -1
# 3             Z                  M                       No                -1
# 4             Z                  M                       No                -1
# 5             Z                  M                       No                -1
# 6             Z                  M                       No                -1
# 7             Z                  M                       No                -1
# 8             Z                  M                       No                -1
# 9             Z                  M                       No                -1
#
#   EMLAGE_DIS_DESCR EMLAGE_DOMAIN_CNTRY_MATCH EMLAGE_DOMAIN_CORP  \
# 0                Z                         Z                  Z
# 1  High Confidence                       Yes                 No
# 2  High Confidence                       Yes                 No
# 3  High Confidence                       Yes                 No
# 4  High Confidence                       Yes                 No
# 5  High Confidence                       Yes                 No
# 6  High Confidence                       Yes                 No
# 7  High Confidence                       Yes                 No
# 8  High Confidence                       Yes                 No
# 9  High Confidence                       Yes                 No
#
#   EMLAGE_DOMAIN_COUNTRY EMLAGE_DOMAIN_EXISTS EMLAGE_DOMAIN_RISK_CNTRY  ...  \
# 0                     Z                    Z                        Z  ...
# 1                    US                  Yes                       No  ...
# 2                    US                  Yes                       No  ...
# 3                    US                  Yes                       No  ...
# 4                    US                  Yes                       No  ...
# 5                    US                  Yes                       No  ...
# 6                    US                  Yes                       No  ...
# 7                    US                  Yes                       No  ...
# 8                    US                  Yes                       No  ...
# 9                    US                  Yes                       No  ...
#
#   EMLAGE_STATUS FM_SCAN_CODE ID_STN_STATE_MATCH_IND NYCE_AVAIL_FUNDS  \
# 0             Z            Z                      Z                Z
# 1      Verified            M                NULL_ID                U
# 2      Verified            M                NULL_ID                U
# 3     Certified            M                NULL_ID                U
# 4      Verified            M                NULL_ID                U
# 5      Verified            M                NULL_ID                U
# 6      Verified            M                NULL_ID                U
# 7      Verified            M                NULL_ID                U
# 8      Verified            M                NULL_ID                U
# 9      Verified            M                NULL_ID                U
#
#   NYCE_RESP_CODE POSITIVE_GRADE SPECTRUM_ALERT_CODE1 SPECTRUM_ALERT_CODE2  \
# 0              Z              Z                    Z                    Z
# 1              U             -1                    Z                    Z
# 2              U             -1                    Z                    Z
# 3              U             -1                    Z                    Z
# 4              U             -1                 300A                    Z
# 5              U             -1                    Z                    Z
# 6              U             -1                    Z                    Z
# 7              U             -1                 300A                    Z
# 8              U             -1                    Z                    Z
# 9              U             -1                    Z                    Z
#
#   SPECTRUM_ALERT_CODE3 SPECTRUM_RSS2302_REASON_CODE5
# 0                    Z                             Z
# 1                    Z                             Z
# 2                    Z                             Z
# 3                    Z                             Z
# 4                    Z                             Z
# 5                    Z                             Z
# 6                    Z                             Z
# 7                    Z                             Z
# 8                    Z                             Z
# 9                    Z                             Z
#
# [10 rows x 31 columns]

# %%
#now merge the categorical and numeric columns back together
imputed_X = pd.concat([imputed_num_X, imputed_char_X], axis=1)

# %%
#run smote
from imblearn.over_sampling import SMOTENC
smote = SMOTENC(random_state=42, categorical_features=categorical_cols)
X_resampled, y_resampled = smote.fit_resample(imputed_X, y)

# %%
X_resampled = pd.DataFrame(X_resampled, columns=imputed_X.columns)
y_resampled = pd.DataFrame(y_resampled, columns=['OUTCOME'])

# %%
df_resampled = pd.concat([X_resampled,y_resampled], axis=1)

# %%
df_resampled['OUTCOME'].value_counts()
# Out:
# OUTCOME
# NO ATTEMPTS    23863
# GOOD           23863
# LOSS           23863
# DECLINED       23863
# Name: count, dtype: int64

# %%
df_resampled.to_csv("/workspaces/workspace/synthetic_test_result.csv", index=False)

# %%
categorical_cols = [cname for cname in X.columns if
                    X[cname].nunique() >= 21 and 
                    X[cname].dtype == "object"]
categorical_cols
# Out:
# ['CCHXMC730001X',
#  'EMLAGE_DOMAIN_CAT',
#  'EMLAGE_DOMAIN_CO',
#  'EMLAGE_DOMAIN_NAME',
#  'SPECTRUM_RSS2302_REASON_CODE1',
#  'SPECTRUM_RSS2302_REASON_CODE2',
#  'SPECTRUM_RSS2302_REASON_CODE3',
#  'SPECTRUM_RSS2302_REASON_CODE4',
#  'STATION_STATE']
